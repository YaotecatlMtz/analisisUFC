# %%
import pandas as pd
df = pd.read_csv('ufc-fight-metadata.csv',encoding='utf-8')
dfBackup = df.copy()
fightersName = df["FIGHT_WINNER"] + ' referee: ' + df['FIGHT_REFEREE']
fightersName
# Out:
# 0                Derrick Lewis referee: Mark Smith
# 1                Belal Muhammad referee: Herb Dean
# 2               Amanda Lemos referee: Jason Herzog
# 3               Ricky Simon referee: Chris Tognoni
# 4             Mateusz Gamrot referee: Jason Herzog
#                            ...
# 6716    Marcos Rogerio de Lima referee: Mark Smith
# 6717           Junyong Park referee: Chris Tognoni
# 6718               Steve Garcia referee: Herb Dean
# 6719               Cody Durden referee: Mark Smith
# 6720    Christian Rodriguez referee: Chris Tognoni
# Length: 6721, dtype: object

# %%
df.query("FIGHT_WINNER == 'Derrick Lewis'")
# Out:
#       FIGHT_ID  EVENT_ID                           FIGHT_NAME  \
# 0         9532      1131        Derrick Lewis v Chris Daukaus
# 440       9972      1168       Curtis Blaydes v Derrick Lewis
# 712      10244      1193      Derrick Lewis v Aleksei Oleinik
# 934      10466      1212          Derrick Lewis v Ilir Latifi
# 1031     10563      1220        Derrick Lewis v Blagoy Ivanov
# 1608     11140      1267     Derrick Lewis v Alexander Volkov
# 1721     11253      1276      Francis Ngannou v Derrick Lewis
# 1887     11419      1290        Derrick Lewis v Marcin Tybura
# 2355     11887      1330        Derrick Lewis v Travis Browne
# 2447     11979      1338  Derrick Lewis v Shamil Abdurakhimov
# 2695     12227      1359           Roy Nelson v Derrick Lewis
# 2793     12325      1367      Derrick Lewis v Gabriel Gonzaga
# 2862     12394      1372     Derrick Lewis v Damian Grabowski
# 3023     12555      1385         Derrick Lewis v Viktor Pesta
# ...
